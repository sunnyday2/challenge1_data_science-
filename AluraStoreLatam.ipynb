# %% [markdown]
# <a href="https://colab.research.google.com/github/sunnyday2/challenge1_data_science-/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda1 = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda1.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %%
tienda2.head()
# Out:
#            Producto  Categoría del Producto    Precio  Costo de envío  \
# 0  Silla de oficina                 Muebles  283600.0         15300.0
# 1         Pandereta  Instrumentos musicales   76800.0          2300.0
# 2         Cama king                 Muebles  443300.0         23800.0
# 3         Cama king                 Muebles  906200.0         46400.0
# 4  Silla de oficina                 Muebles  397800.0         19400.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      04/08/2021  Izabela de León        Medellín             1
# 1      26/11/2020   Blanca Ramirez        Medellín             3
# 2      22/10/2021  Izabela de León         Pereira             5
# 3      04/05/2022    Maria Alfonso            Cali             5
# 4      26/02/2022    Lucas Olivera          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0               Nequi                   1  6.25184 -75.56359
# ...

# %%
tienda3.head()
# Out:
#             Producto  Categoría del Producto     Precio  Costo de envío  \
# 0   Secadora de ropa       Electrodomésticos  1285100.0         66600.0
# 1      Mesa de noche                 Muebles   290100.0         13600.0
# 2  Guitarra acústica  Instrumentos musicales   303500.0         17400.0
# 3  Balón de voleibol    Deportes y diversión    58800.0          3300.0
# 4            Armario                 Muebles   521100.0         25900.0
#
#   Fecha de Compra        Vendedor Lugar de Compra  Calificación  \
# 0      17/12/2021   Camila Rivera     Santa Marta             4
# 1      10/02/2021   Maria Alfonso            Cali             3
# 2      22/01/2023   Lucas Olivera          Bogotá             5
# 3      22/03/2022     Pedro Gomez    Barranquilla             4
# 4      12/01/2022  Blanca Ramirez          Bogotá             1
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   4  11.24079 -74.19904
# ...

# %%
tienda4.head()
# Out:
#               Producto Categoría del Producto     Precio  Costo de envío  \
# 0         Lavavajillas      Electrodomésticos  1084800.0         56000.0
# 1             Cama box                Muebles   473800.0         25400.0
# 2  Balón de baloncesto   Deportes y diversión    23700.0             0.0
# 3  Modelado predictivo                 Libros    57700.0          1300.0
# 4          Auriculares           Electrónicos   138900.0          5600.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      11/11/2022    Rafael Acosta          Bogotá             4
# 1      03/01/2020  Izabela de León          Cúcuta             5
# 2      25/12/2022    Maria Alfonso        Medellín             5
# 3      23/11/2021    Lucas Olivera        Medellín             3
# 4      25/04/2022   Blanca Ramirez          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0  Tarjeta de crédito                   3  4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %% [markdown]
# ## **Ingreso total por cada tienda**

# %% [markdown]
# En este primer análisis, debes calcular el ingreso total de cada tienda. Sumando los valores de la columna Precio de cada conjunto de datos de la tienda para estimar los ingresos.

# %%
ventas_tienda1 = tienda1['Precio'].sum()
ventas_tienda2 = tienda2['Precio'].sum()
ventas_tienda3 = tienda3['Precio'].sum()
ventas_tienda4 = tienda4['Precio'].sum()

print('** Ventas **')
print(f'Tienda 1: {ventas_tienda1}')
print(f'Tienda 2: {ventas_tienda2}')
print(f'Tienda 3: {ventas_tienda3}')
print(f'Tienda 4: {ventas_tienda4}')
# Out:
# ** Ventas **
# Tienda 1: 1150880400.0
# Tienda 2: 1116343500.0
# Tienda 3: 1098019600.0
# Tienda 4: 1038375700.0

# %% [markdown]
# ## 2. Ventas por categoría

# %% [markdown]
# En este debes calcular la cantidad de productos vendidos por categoría en cada tienda. La idea es agrupar los datos por categoría y contar el número de ventas de cada tipo, mostrando las categorías más populares de cada tienda.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Asignar tienda
tienda1['Tienda'] = 'Tienda 1'
tienda2['Tienda'] = 'Tienda 2'
tienda3['Tienda'] = 'Tienda 3'
tienda4['Tienda'] = 'Tienda 4'

tienda1['Ventas'] = ventas_tienda1
tienda2['Ventas'] = ventas_tienda2
tienda3['Ventas'] = ventas_tienda3
tienda4['Ventas'] = ventas_tienda4

# Función para agrupar por categoría y tienda
def ventas_categoria(productos: pd.DataFrame) -> pd.DataFrame:
    ventas = productos.groupby(['Categoría del Producto', 'Tienda'])[['Producto']].count()
    ventas = ventas.rename(columns={'Producto': 'Cantidad'}).sort_values(by='Cantidad', ascending=False)
    return ventas

# Obtener ventas por tienda
v1 = ventas_categoria(tienda1)
v2 = ventas_categoria(tienda2)
v3 = ventas_categoria(tienda3)
v4 = ventas_categoria(tienda4)

# Unir todos los DataFrames
ventas_all = pd.concat([tienda1, tienda2, tienda3, tienda4])
ventas_categoria_all = pd.concat([v1, v2, v3, v4])

ventas_categoria_all
# Out:
#                                   Cantidad
# Categoría del Producto  Tienda
# Muebles                 Tienda 1       465
# Electrónicos            Tienda 1       448
# Juguetes                Tienda 1       324
# Electrodomésticos       Tienda 1       312
# Deportes y diversión    Tienda 1       284
# Instrumentos musicales  Tienda 1       182
# Libros                  Tienda 1       173
# Artículos para el hogar Tienda 1       171
# Muebles                 Tienda 2       442
# Electrónicos            Tienda 2       422
# Juguetes                Tienda 2       313
# Electrodomésticos       Tienda 2       305
# Deportes y diversión    Tienda 2       275
# Instrumentos musicales  Tienda 2       224
# Libros                  Tienda 2       197
# Artículos para el hogar Tienda 2       181
# Muebles                 Tienda 3       499
# Electrónicos            Tienda 3       451
# Juguetes                Tienda 3       315
# Electrodomésticos       Tienda 3       278
# ...

# %% [markdown]
# ## 3. Calificación promedio de la tienda

# %% [markdown]
# En este paso, debes calcular las calificaciones promedio de los clientes para cada tienda. El objetivo es conocer la satisfacción del cliente con los productos vendidos.

# %%
tienda1_calificacion = round(tienda1['Calificación'].mean(), 2)
tienda2_calificacion = round(tienda2['Calificación'].mean(), 2)
tienda3_calificacion = round(tienda3['Calificación'].mean(), 2)
tienda4_calificacion = round(tienda4['Calificación'].mean(), 2)

print('** Calificaciones promedio por la tienda **')
print(f'Tienda 1: {tienda1_calificacion}')
print(f'Tienda 2: {tienda2_calificacion}')
print(f'Tienda 3: {tienda3_calificacion}')
print(f'Tienda 4: {tienda4_calificacion}')
# Out:
# ** Calificaciones promedio por la tienda **
# Tienda 1: 3.98
# Tienda 2: 4.04
# Tienda 3: 4.05
# Tienda 4: 4.0

# %% [markdown]
# ## 4. Productos más y menos vendidos

# %% [markdown]
# En este paso, debes identificar qué productos fueron los más vendidos y los menos vendidos en cada tienda. Visualiza los resultados para que quede claro qué productos destacaron en ventas en cada tienda.

# %% [markdown]
# ### Mayor y menor cantidades de ventas de los productos

# %%
def productos(productos: pd.DataFrame) -> pd.DataFrame:
    max_vendido = int(productos.groupby(['Producto', 'Tienda'])[['Producto']].count().max().iloc[0])
    min_vendido = int(productos.groupby(['Producto', 'Tienda'])[['Producto']].count().min().iloc[0])

    #print(max_vendido)
    #print(min_vendido)

    ventas = productos.groupby(['Producto', 'Tienda'])[['Producto']].count()
    #print(ventas)

    ventas.rename(
        columns={
            "Producto": "Cantidad",
        }
        , inplace=True
    )

    tienda_productos = ventas.query('Cantidad in (@max_vendido, @min_vendido)').sort_values(by='Cantidad', ascending=False)
    return tienda_productos

tienda1_productos = productos(tienda1)
tienda2_productos = productos(tienda2)
tienda3_productos = productos(tienda3)
tienda4_productos = productos(tienda4)

print('** Productos más y menos vendidos en cada tienda **')
print(f'\n** Tienda 1:')
print(f'\t\t {tienda1_productos}')

print(f'\n** Tienda 2:')
print(f'\t\t {tienda2_productos}')

print(f'\n** Tienda 3:')
print(f'\t\t {tienda3_productos}')

print(f'\n** Tienda 4:')
print(f'\t\t {tienda4_productos}')
# Out:
# ** Productos más y menos vendidos en cada tienda **
#
# ** Tienda 1:
# 		                                     Cantidad
# Producto                  Tienda
# Armario                   Tienda 1        60
# TV LED UHD 4K             Tienda 1        60
# Microondas                Tienda 1        60
# Celular ABXY              Tienda 1        33
# Auriculares con micrófono Tienda 1        33
#
# ** Tienda 2:
# 		                                     Cantidad
# Producto                  Tienda
# Iniciando en programación Tienda 2        65
# Juego de mesa             Tienda 2        32
#
# ** Tienda 3:
# 		                                   Cantidad
# Producto                Tienda
# Kit de bancas           Tienda 3        57
# Bloques de construcción Tienda 3        35
#
# ** Tienda 4:
# 		                              Cantidad
# Producto           Tienda
# Cama box           Tienda 4        62
# Guitarra eléctrica Tienda 4        33

# %% [markdown]
# ### Mayor y menor valor de ventas de los productos

# %%
# Calcular valor generado de las ventas
def productos_total_venta(productos: pd.DataFrame) -> pd.DataFrame:
    max_vendido = int(productos.groupby(['Producto', 'Tienda'])[['Precio']].sum().max().iloc[0])
    min_vendido = int(productos.groupby(['Producto', 'Tienda'])[['Precio']].sum().min().iloc[0])

    #print(max_vendido)
    #print(min_vendido)

    ventas = productos.groupby(['Producto', 'Tienda'])[['Precio']].sum()
    #print(ventas)

    ventas.rename(
        columns={
            "Precio": "Total",
        }
        , inplace=True
    )

    tienda_productos = ventas.query('Total in (@max_vendido, @min_vendido)').sort_values(by='Total', ascending=False)
    return tienda_productos

tienda1_productos_total_venta = productos_total_venta(tienda1)
#print(f'Tipo: {type(tienda1_productos_total_venta)}')
tienda2_productos_total_venta = productos_total_venta(tienda2)
tienda3_productos_total_venta = productos_total_venta(tienda3)
tienda4_productos_total_venta = productos_total_venta(tienda4)


print('** Productos que generaron mayor y menor ingresos en cada tienda **')
print(f'\n** Tienda 1:')
print(f'\t\t {tienda1_productos_total_venta}')

print(f'\n** Tienda 2:')
print(f'\t\t {tienda2_productos_total_venta}')

print(f'\n** Tienda 3:')
print(f'\t\t {tienda3_productos_total_venta}')

print(f'\n** Tienda 4:')
print(f'\t\t {tienda4_productos_total_venta}')
# Out:
# ** Productos que generaron mayor y menor ingresos en cada tienda **
#
# ** Tienda 1:
# 		                                    Total
# Producto           Tienda
# TV LED UHD 4K      Tienda 1  142150200.0
# Cuerda para saltar Tienda 1     652800.0
#
# ** Tienda 2:
# 		                                 Total
# Producto        Tienda
# Iphone 15       Tienda 2  113225800.0
# Cubo mágico 8x8 Tienda 2     643600.0
#
# ** Tienda 3:
# 		                                Total
# Producto        Tienda
# Refrigerador    Tienda 3  99889700.0
# Cubo mágico 8x8 Tienda 3    640400.0
#
# ** Tienda 4:
# 		                                   Total
# Producto           Tienda
# Iphone 15          Tienda 4  96697500.0
# Cuerda para saltar Tienda 4    704800.0

# %% [markdown]
# ### Total de Ventas vs Cantidades Vendidas

# %%
# Calcular valor generado de las ventas y cantidades vendidas
def productos_venta(productos: pd.DataFrame) -> pd.DataFrame:
    ventas = pd.DataFrame()
    ventas['Total'] = productos.groupby(['Producto', 'Tienda'])[['Precio']].sum()
    ventas['Cantidad'] = productos.groupby(['Producto', 'Tienda'])[['Producto']].count()
    #print(ventas)
    tienda_productos = ventas.sort_values(by='Total', ascending=False)

    max_vendido = int(tienda_productos.groupby(['Producto', 'Tienda'])[['Total']].sum().max().iloc[0])
    min_vendido = int(tienda_productos.groupby(['Producto', 'Tienda'])[['Total']].sum().min().iloc[0])
    #print(f'max: {max_vendido}')
    #print(f'min: {min_vendido}')

    tienda_productos = tienda_productos.query('Total in (@max_vendido, @min_vendido)').sort_values(by='Total', ascending=False)

    return tienda_productos

tienda1_productos_venta = productos_venta(tienda1)
tienda2_productos_venta = productos_venta(tienda2)
tienda3_productos_venta = productos_venta(tienda3)
tienda4_productos_venta = productos_venta(tienda4)

print('** Valor de ventas de productos y sus cantidades en cada tienda **')
print(f'\n** Tienda 1:')
print(f'\t\t {tienda1_productos_venta}')

print(f'\n** Tienda 2:')
print(f'\t\t {tienda2_productos_venta}')

print(f'\n** Tienda 3:')
print(f'\t\t {tienda3_productos_venta}')

print(f'\n** Tienda 4:')
print(f'\t\t {tienda4_productos_venta}')
# Out:
# ** Valor de ventas de productos y sus cantidades en cada tienda **
#
# ** Tienda 1:
# 		                                    Total  Cantidad
# Producto           Tienda
# TV LED UHD 4K      Tienda 1  142150200.0        60
# Cuerda para saltar Tienda 1     652800.0        40
#
# ** Tienda 2:
# 		                                 Total  Cantidad
# Producto        Tienda
# Iphone 15       Tienda 2  113225800.0        55
# Cubo mágico 8x8 Tienda 2     643600.0        45
#
# ** Tienda 3:
# 		                                Total  Cantidad
# Producto        Tienda
# Refrigerador    Tienda 3  99889700.0        50
# Cubo mágico 8x8 Tienda 3    640400.0        44
#
# ** Tienda 4:
# 		                                   Total  Cantidad
# Producto           Tienda
# Iphone 15          Tienda 4  96697500.0        48
# Cuerda para saltar Tienda 4    704800.0        43

# %% [markdown]
# ## 5. Envío promedio por tienda

# %% [markdown]
# En este paso, debes calcular el costo de envío promedio para cada tienda. El objetivo es comprender cuánto se gasta, en promedio, en el envío de cada tienda.

# %%
tienda1_envio = round(tienda1['Costo de envío'].mean(), 2)
tienda2_envio = round(tienda2['Costo de envío'].mean(), 2)
tienda3_envio = round(tienda3['Costo de envío'].mean(), 2)
tienda4_envio = round(tienda4['Costo de envío'].mean(), 2)

print('** Costo de envío promedio por la tienda **')
print(f'Tienda 1: {tienda1_envio}')
print(f'Tienda 2: {tienda2_envio}')
print(f'Tienda 3: {tienda3_envio}')
print(f'Tienda 4: {tienda4_envio}')
# Out:
# ** Costo de envío promedio por la tienda **
# Tienda 1: 26018.61
# Tienda 2: 25216.24
# Tienda 3: 24805.68
# Tienda 4: 23459.46

# %% [markdown]
# # **Generando gráfico**

# %% [markdown]
#  Los gráficos deben complementar el análisis realizado, resaltando los puntos más relevantes, como los ingresos de la tienda, la distribución de categorías de productos, las opiniones de los clientes, los productos más vendidos y/o los costes de envío.

# %% [markdown]
# ## **Ingreso porcentual total por cada tienda**

# %%
import matplotlib.pyplot as plt

# Datos: DataFrames por tienda
ventas_tiendas = [ventas_tienda1, ventas_tienda2, ventas_tienda3, ventas_tienda4]
ventas_tiendas_ordenadas = sorted(ventas_tiendas, reverse=True)
tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']

# Encontrar índice del mayor valor
mayor_idx = ventas_tiendas_ordenadas[0]

# Crear lista de "explode": todos 0 excepto el mayor
explode = [0.1 if i == mayor_idx else 0 for i in range(len(ventas_tiendas))]

# Graficar pastel
plt.figure(figsize=(8, 8))
plt.pie(
    x=ventas_tiendas_ordenadas,
    labels=tiendas,
    autopct='%1.1f%%',
    startangle=140,
    explode=explode,
    shadow=True  # Efecto tipo 3D
)
plt.title('Porcentaje de Ventas Totales por Tienda')
plt.axis('equal')  # Asegura que el pastel sea circular
plt.show()

# %% [markdown]
# ## **Venta por categoría**

# %%
# Pivotear para tener tiendas como columnas y categorías como filas
ventas_pivot = ventas_categoria_all.reset_index().pivot(index='Categoría del Producto', columns='Tienda', values='Cantidad').fillna(0)

# Ordenar categorías por total descendente
ventas_pivot['Total'] = ventas_pivot.sum(axis=1)
ventas_pivot = ventas_pivot.sort_values(by='Total', ascending=False)
ventas_pivot = ventas_pivot.drop(columns='Total')

# ----------------------------
# Graficar barras horizontales agrupadas
# ----------------------------
plt.figure(figsize=(12, 8))
bar_width = 0.2
y_pos = range(len(ventas_pivot))

for i, tienda in enumerate(ventas_pivot.columns):
    plt.barh(
        [y + i * bar_width for y in y_pos],
        ventas_pivot[tienda],
        height=bar_width,
        label=tienda
    )

# Etiquetas y formato
plt.yticks([y + bar_width * 1.5 for y in y_pos], ventas_pivot.index)
plt.xlabel("Cantidad Vendida")
plt.title("Ventas por Categoría y Tienda")
plt.legend()
plt.gca().invert_yaxis()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Calificaciones de Productos**

# %%
# -------------------------------
# Gráfico combinado: Opiniones (Calificación) vs Productos más evaluados
# -------------------------------
# Obtener los productos con más evaluaciones (más registros)
evaluaciones = ventas_all.groupby("Producto").agg({
    "Calificación": ["count", "mean"]
}).reset_index()

evaluaciones.columns = ["Producto", "Cantidad_Evaluaciones", "Promedio_Calificación"]
top_productos = evaluaciones.sort_values("Cantidad_Evaluaciones", ascending=False).head(10)

fig, ax1 = plt.subplots(figsize=(10, 5))

# Barras: Cantidad de evaluaciones
ax1.bar(top_productos["Producto"], top_productos["Cantidad_Evaluaciones"], color="lightgreen", label="Evaluaciones")
ax1.set_ylabel("Cantidad de Evaluaciones", color="green")
ax1.tick_params(axis='y', labelcolor='green')
ax1.set_xticklabels(top_productos["Producto"], rotation=45, ha='right')

# Línea: Promedio de calificación
ax2 = ax1.twinx()
ax2.plot(top_productos["Producto"], top_productos["Promedio_Calificación"], color="red", marker='o', label="Promedio Calificación")
ax2.set_ylabel("Promedio de Calificación", color="red")
ax2.tick_params(axis='y', labelcolor='red')

plt.title("Productos Más Evaluados y Opiniones")
fig.tight_layout()
plt.show()
# Out:
# <ipython-input-98-789340582>:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(top_productos["Producto"], rotation=45, ha='right')

# %% [markdown]
# ## **Productos más y menos vendidos**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

print('** Tienda 1 **')
print(f'{tienda1_productos_venta.head()}')

print('** Tienda 2 **')
print(f'{tienda2_productos_venta.head()}')

print('** Tienda 3 **')
print(f'{tienda3_productos_venta.head()}')

print('** Tienda 4 **')
print(f'{tienda4_productos_venta.head()}')

# Combinar los 4 DataFrames
productos_total_venta_all = pd.concat([tienda1_productos_venta, tienda2_productos_venta
                                       , tienda3_productos_venta, tienda4_productos_venta])

# Ordenar por total (opcional)
productos_total_venta_all = productos_total_venta_all.sort_values(by='Total', ascending=True)
#productos_total_venta_all = productos_total_venta_all.reset_index()
print('** Todas las Tiendas **')
print(productos_total_venta_all.head())
print(productos_total_venta_all.info())


# Asignar colores por tienda
#tiendas = productos_total_venta_all["Tienda"].unique()
tiendas = productos_total_venta_all.index.get_level_values('Tienda').unique()
colors = plt.cm.tab10.colors  # Puedes cambiar a plt.cm.Set3.colors para más variedad
color_map = {tienda: colors[i % len(colors)] for i, tienda in enumerate(tiendas)}

# Crear figura
fig, ax = plt.subplots(figsize=(12, 7))

# Dibujar barras
bars = ax.barh(
    y=productos_total_venta_all.index.get_level_values('Producto') + " (" + productos_total_venta_all.index.get_level_values('Tienda') + ")",  # Etiqueta única por producto+tienda
    width=productos_total_venta_all["Total"],
    color=[color_map[tienda] for tienda in productos_total_venta_all.index.get_level_values('Tienda')],
)

# Agregar texto de cantidad
for bar, cantidad in zip(bars, productos_total_venta_all["Cantidad"]):
    x = bar.get_width()
    y = bar.get_y() + bar.get_height() / 2
    ax.text(x + x*0.01, y, str(cantidad), va='center')

# Leyenda personalizada
legend_elements = [Patch(facecolor=color_map[t], label=t) for t in tiendas]
ax.legend(handles=legend_elements, title="Tienda", loc="lower right")

# Etiquetas
ax.set_xlabel("Total")
ax.set_title("Ventas Totales por Producto y Tienda (con Cantidad)")

# Ajustar diseño
plt.tight_layout()
plt.show()
# Out:
# ** Tienda 1 **
#                                    Total  Cantidad
# Producto           Tienda
# TV LED UHD 4K      Tienda 1  142150200.0        60
# Cuerda para saltar Tienda 1     652800.0        40
# ** Tienda 2 **
#                                 Total  Cantidad
# Producto        Tienda
# Iphone 15       Tienda 2  113225800.0        55
# Cubo mágico 8x8 Tienda 2     643600.0        45
# ** Tienda 3 **
#                                Total  Cantidad
# Producto        Tienda
# Refrigerador    Tienda 3  99889700.0        50
# Cubo mágico 8x8 Tienda 3    640400.0        44
# ** Tienda 4 **
#                                   Total  Cantidad
# Producto           Tienda
# Iphone 15          Tienda 4  96697500.0        48
# Cuerda para saltar Tienda 4    704800.0        43
# ** Todas las Tiendas **
#                                   Total  Cantidad
# Producto           Tienda
# Cubo mágico 8x8    Tienda 3    640400.0        44
#                    Tienda 2    643600.0        45
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
x='Producto'
y='Cantidad'
titulo = 'Productos más y menos vendidos por la Tienda '

# Unir todos los DataFrames
ventas_productos_all = pd.concat([tienda1_productos, tienda2_productos, tienda3_productos, tienda4_productos])

# Pivotear para tener tiendas como columnas y categorías como filas
ventas_productos_pivot = ventas_productos_all.reset_index().pivot(index='Producto', columns='Tienda', values='Cantidad').fillna(0)

# Ordenar categorías por total descendente
ventas_productos_pivot['Total'] = ventas_productos_pivot.sum(axis=1)
ventas_productos_pivot = ventas_productos_pivot.sort_values(by='Total', ascending=False)
ventas_productos_pivot = ventas_productos_pivot.drop(columns='Total')

# ----------------------------
# Graficar barras horizontales agrupadas
# ----------------------------
plt.figure(figsize=(12, 8))
bar_width = 0.2
y_pos = range(len(ventas_productos_pivot))

for i, tienda in enumerate(ventas_productos_pivot.columns):
    plt.barh(
        [y + i * bar_width for y in y_pos],
        ventas_productos_pivot[tienda],
        height=bar_width,
        label=tienda
    )

# Etiquetas y formato
plt.yticks([y + bar_width * 1.5 for y in y_pos], ventas_productos_pivot.index)
plt.xlabel("Cantidad Vendida")
plt.title("Ventas Producto en Tienda")
plt.legend()
plt.gca().invert_yaxis()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Costes de Envío**

# %%
# Agrupar por tienda y calcular ingresos y costes de envío
resumen = ventas_all.groupby("Tienda").agg({
    "Precio": "sum",
    "Costo de envío": "sum"
}).reset_index()

# -------------------------------
# Gráfico de líneas – Costes de envío por tienda
# -------------------------------
# Gráfico combinado
fig, ax1 = plt.subplots(figsize=(8, 6))

# Barras para ingresos
ax1.bar(resumen["Tienda"], resumen["Precio"], color='skyblue', label="Ingresos")
ax1.set_ylabel("Ingresos", color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# Eje secundario para costos de envío
ax2 = ax1.twinx()
ax2.plot(resumen["Tienda"], resumen["Costo de envío"], color='red', marker='o', linewidth=2, label="Costo de envío")
ax2.set_ylabel("Costo de envío", color='red')
ax2.tick_params(axis='y', labelcolor='red')

# Título y leyenda
plt.title("Ingresos vs. Costos de Envío por Tienda")
fig.tight_layout()
plt.show()

# %% [markdown]
# ## **Vendedores destacados**

# %%
def mejor_vendedor(df: pd.DataFrame) -> pd.DataFrame:
  ventas_por_vendedor = df.groupby(['Tienda', 'Vendedor'])['Precio'].sum().reset_index()
  mejor_por_tienda = ventas_por_vendedor.sort_values('Precio', ascending=False).head(1)
  return mejor_por_tienda

# Unir todos los datos de mejores vendedores en cada tienda
ventas_vendedor = []
for df in [tienda1, tienda2, tienda3, tienda4]:
  ventas_vendedor.append(mejor_vendedor(df))

mejores_vendedores = pd.DataFrame(columns=['Tienda', 'Vendedor', 'Total de Ventas'])
mejores_vendedores[['Tienda', 'Vendedor', 'Total de Ventas']] = pd.concat(ventas_vendedor, ignore_index=True)
mejores_vendedores.sort_values(by='Total de Ventas', inplace=True, ascending=False)
mejores_vendedores.reset_index(drop=True, inplace=True)
print(mejores_vendedores)


# Gráfico de torta
plt.figure(figsize=(8, 6))
plt.pie(mejores_vendedores['Total de Ventas'], labels=mejores_vendedores['Tienda'] + ':' + mejores_vendedores['Vendedor'], autopct='%1.1f%%', startangle=140)
plt.title('Top Mejores Vendedores de cada Tienda)')
plt.axis('equal')  # Asegura que el gráfico sea un círculo
plt.show()
# Out:
#      Tienda         Vendedor  Total de Ventas
# 0  Tienda 1    Maria Alfonso      101528700.0
# 1  Tienda 3    Maria Alfonso       96328500.0
# 2  Tienda 4    Felipe Santos       95432000.0
# 3  Tienda 2  Izabela de León       91812200.0

# %% [markdown]
# # **Informe final**

# %% [markdown]
# El objetivo de este informe es identificar cuál de las cuatro tiendas analizadas (Tienda 1 a Tienda 4) representa la mejor opción para que el Sr. Juan comercialice sus productos. Para ello, se analizaron múltiples factores relevantes: ingresos totales, calificaciones de los clientes, productos más y menos vendidos, cantidades y montos generados, así como el costo promedio de envío. A continuación, se presentan los hallazgos clave y la recomendación final, fundamentada en los datos recopilados y visualizaciones generadas.

# %% [markdown]
# ## **Categorias y productos destacados**

# %% [markdown]
# El análisis reveló que las categorías **Electrónica** y **Muebles** concentran la mayor parte de las ventas, lo que indica una fuerte demanda del público por productos tecnológicos y del hogar. Estas categorías deben ser prioridad en promociones y mantenerse con buen stock para maximizar los beneficios.
#
#
# Los productos con **mayores ingresos** generados fueron:
#
# 1.   TV LED UHD 4K
# 2.   iPhone 15
# 3.   Refrigerador
#
# Por otro lado, los productos con **menor rentabilidad** fueron:
#
# 1.   Cubo mágico 8x8
# 2.   Cuerda para saltar
#
# Esto sugiere que los artículos de bajo precio o nicho presentan menor rotación y retorno económico, por lo que se recomienda reevaluar su permanencia en inventario o incluirlos solo como complementos.

# %% [markdown]
# ## **Producto con menor evaluación**

# %% [markdown]
# Un hallazgo importante es que algunos productos muy vendidos no necesariamente son bien evaluados. En particular, el producto **Modelado Predictivo** recibió una de las calificaciones más bajas por parte de los clientes. Se recomienda analizar las causas —ya sea en su funcionalidad, servicio postventa o descripción del producto— para implementar mejoras que fortalezcan la experiencia del cliente.

# %% [markdown]
# ## **Vendedores destacados**

# %% [markdown]
# El análisis de desempeño individual de los vendedores reveló que María Alonso fue la mejor vendedora en Tienda 1 y Tienda 3, generando los mayores volúmenes de ventas. Su enfoque exitoso debería ser compartido con los equipos de las demás tiendas, especialmente Tienda 4, que presenta resultados ligeramente inferiores.

# %% [markdown]
# ## **Desempeño General de las Tiendas**

# %% [markdown]
# *   **Tienda 1** lidera en ingresos, lo que la convierte en una fuerte candidata desde el punto de vista financiero.
#
# *   **Tienda 3**, aunque tercera en ingresos, tiene la mejor calificación de clientes, lo cual refleja una excelente experiencia de compra.
#
# *   **Tienda 4** destaca por tener el costo de envío más bajo, lo que la hace competitiva en precios finales, aunque sus ingresos son levemente inferiores.

# %% [markdown]
# ## **Recomendación Final**

# %% [markdown]
# Tras evaluar todos los factores, **se recomienda que el Sr. Juan inicie la comercialización de sus productos en la Tienda 3**, por las siguientes razones:
#
# *   Alto volumen de ingresos con productos de buena rotación.
#
# *   **Mejor valoración por parte de los clientes**, lo que sugiere mayor fidelización.
#
# *   Costo de envío moderado que mantiene la competitividad sin sacrificar calidad.
#
# *   Existencia de una **vendedora destacada (María Alonso)** que podría potenciar aún más las ventas mediante mentoría interna.
#
# Adicionalmente, se sugiere:
#
# *   Fomentar la venta de productos tecnológicos de alto valor unitario, como televisores y smartphones.
#
# *   Realizar ajustes en productos con baja rotación o mala evaluación.
#
# *   Promover el intercambio de buenas prácticas entre vendedores, en especial desde las tiendas con mejor desempeño hacia aquellas con menor rendimiento.
