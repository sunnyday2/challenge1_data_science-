# %% [markdown]
# <a href="https://colab.research.google.com/github/sunnyday2/challenge1_data_science-/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda1 = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda1.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# 1  Tarjeta de crédito                   4   6.25184 -75.56359
# 2  Tarjeta de crédito                   1  10.39972 -75.51444
# 3               Nequi                   1   3.43722 -76.52250
# 4               Nequi                   1   6.25184 -75.56359

# %%
tienda2.head()
# Out:
#            Producto  Categoría del Producto    Precio  Costo de envío  \
# 0  Silla de oficina                 Muebles  283600.0         15300.0
# 1         Pandereta  Instrumentos musicales   76800.0          2300.0
# 2         Cama king                 Muebles  443300.0         23800.0
# 3         Cama king                 Muebles  906200.0         46400.0
# 4  Silla de oficina                 Muebles  397800.0         19400.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      04/08/2021  Izabela de León        Medellín             1
# 1      26/11/2020   Blanca Ramirez        Medellín             3
# 2      22/10/2021  Izabela de León         Pereira             5
# 3      04/05/2022    Maria Alfonso            Cali             5
# 4      26/02/2022    Lucas Olivera          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0               Nequi                   1  6.25184 -75.56359
# 1  Tarjeta de crédito                   4  6.25184 -75.56359
# 2  Tarjeta de crédito                  10  4.81333 -75.69611
# 3  Tarjeta de crédito                  10  3.43722 -76.52250
# 4  Tarjeta de crédito                   3  4.60971 -74.08175

# %%
tienda3.head()
# Out:
#             Producto  Categoría del Producto     Precio  Costo de envío  \
# 0   Secadora de ropa       Electrodomésticos  1285100.0         66600.0
# 1      Mesa de noche                 Muebles   290100.0         13600.0
# 2  Guitarra acústica  Instrumentos musicales   303500.0         17400.0
# 3  Balón de voleibol    Deportes y diversión    58800.0          3300.0
# 4            Armario                 Muebles   521100.0         25900.0
#
#   Fecha de Compra        Vendedor Lugar de Compra  Calificación  \
# 0      17/12/2021   Camila Rivera     Santa Marta             4
# 1      10/02/2021   Maria Alfonso            Cali             3
# 2      22/01/2023   Lucas Olivera          Bogotá             5
# 3      22/03/2022     Pedro Gomez    Barranquilla             4
# 4      12/01/2022  Blanca Ramirez          Bogotá             1
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   4  11.24079 -74.19904
# 1  Tarjeta de crédito                   1   3.43722 -76.52250
# 2  Tarjeta de crédito                   3   4.60971 -74.08175
# 3  Tarjeta de crédito                   6  10.96854 -74.78132
# 4  Tarjeta de crédito                   1   4.60971 -74.08175

# %%
tienda4.head()
# Out:
#               Producto Categoría del Producto     Precio  Costo de envío  \
# 0         Lavavajillas      Electrodomésticos  1084800.0         56000.0
# 1             Cama box                Muebles   473800.0         25400.0
# 2  Balón de baloncesto   Deportes y diversión    23700.0             0.0
# 3  Modelado predictivo                 Libros    57700.0          1300.0
# 4          Auriculares           Electrónicos   138900.0          5600.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      11/11/2022    Rafael Acosta          Bogotá             4
# 1      03/01/2020  Izabela de León          Cúcuta             5
# 2      25/12/2022    Maria Alfonso        Medellín             5
# 3      23/11/2021    Lucas Olivera        Medellín             3
# 4      25/04/2022   Blanca Ramirez          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0  Tarjeta de crédito                   3  4.60971 -74.08175
# 1  Tarjeta de crédito                   2  7.89391 -72.50782
# 2               Nequi                   1  6.25184 -75.56359
# 3               Nequi                   1  6.25184 -75.56359
# 4  Tarjeta de crédito                   7  4.60971 -74.08175

# %% [markdown]
# #1. Análisis de facturación

# %% [markdown]
# ### **Ingreso total por cada tienda**

# %% [markdown]
# En este primer análisis, debes calcular el ingreso total de cada tienda. Sumando los valores de la columna Precio de cada conjunto de datos de la tienda para estimar los ingresos.

# %%
ventas_tienda1 = tienda1['Precio'].sum()
ventas_tienda2 = tienda2['Precio'].sum()
ventas_tienda3 = tienda3['Precio'].sum()
ventas_tienda4 = tienda4['Precio'].sum()

print('** Ventas **')
print(f'Tienda 1: {ventas_tienda1}')
print(f'Tienda 2: {ventas_tienda2}')
print(f'Tienda 3: {ventas_tienda3}')
print(f'Tienda 4: {ventas_tienda4}')
# Out:
# ** Ventas **
# Tienda 1: 1150880400.0
# Tienda 2: 1116343500.0
# Tienda 3: 1098019600.0
# Tienda 4: 1038375700.0

# %% [markdown]
# # 2. Ventas por categoría

# %% [markdown]
# En este debes calcular la cantidad de productos vendidos por categoría en cada tienda. La idea es agrupar los datos por categoría y contar el número de ventas de cada tipo, mostrando las categorías más populares de cada tienda.

# %%
def ventas_categoria(productos: pd.DataFrame) -> pd.DataFrame:
    ventas = productos.groupby('Categoría del Producto')[['Producto']].count()
    ventas.rename(
        columns={
            "Producto": "Cantidad",
        }
        , inplace=True
    )
    return ventas.sort_values(by='Cantidad', ascending=False)

print('** Ventas por categoria **')
print(f'Tienda 1:')
print(f'\t\t {ventas_categoria(tienda1)}')
print(f'Tienda 2:')
print(f'\t\t {ventas_categoria(tienda2)}')
print(f'Tienda 3:')
print(f'\t\t {ventas_categoria(tienda3)}')
print(f'Tienda 4:')
print(f'\t\t {ventas_categoria(tienda4)}')
# Out:
# ** Ventas por categoria **
# Tienda 1:
# 		                          Cantidad
# Categoría del Producto
# Muebles                       465
# Electrónicos                  448
# Juguetes                      324
# Electrodomésticos             312
# Deportes y diversión          284
# Instrumentos musicales        182
# Libros                        173
# Artículos para el hogar       171
# Tienda 2:
# 		                          Cantidad
# Categoría del Producto
# Muebles                       442
# Electrónicos                  422
# Juguetes                      313
# Electrodomésticos             305
# Deportes y diversión          275
# Instrumentos musicales        224
# Libros                        197
# Artículos para el hogar       181
# Tienda 3:
# 		                          Cantidad
# Categoría del Producto
# Muebles                       499
# Electrónicos                  451
# Juguetes                      315
# Electrodomésticos             278
# Deportes y diversión          277
# Libros                        185
# Artículos para el hogar       177
# Instrumentos musicales        177
# Tienda 4:
# 		                          Cantidad
# Categoría del Producto
# Muebles                       480
# Electrónicos                  451
# Juguetes                      338
# Deportes y diversión          277
# Electrodomésticos             254
# Artículos para el hogar       201
# Libros                        187
# Instrumentos musicales        170

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %% [markdown]
# En este paso, debes calcular las calificaciones promedio de los clientes para cada tienda. El objetivo es conocer la satisfacción del cliente con los productos vendidos.

# %%
tienda1_calificacion = round(tienda1['Calificación'].mean(), 2)
tienda2_calificacion = round(tienda2['Calificación'].mean(), 2)
tienda3_calificacion = round(tienda3['Calificación'].mean(), 2)
tienda4_calificacion = round(tienda4['Calificación'].mean(), 2)

print('** Calificaciones promedio por la tienda **')
print(f'Tienda 1: {tienda1_calificacion}')
print(f'Tienda 2: {tienda2_calificacion}')
print(f'Tienda 3: {tienda3_calificacion}')
print(f'Tienda 4: {tienda4_calificacion}')
# Out:
# ** Calificaciones promedio por la tienda **
# Tienda 1: 3.98
# Tienda 2: 4.04
# Tienda 3: 4.05
# Tienda 4: 4.0

# %% [markdown]
# # 4. Productos más y menos vendidos

# %% [markdown]
# En este paso, debes identificar qué productos fueron los más vendidos y los menos vendidos en cada tienda. Visualiza los resultados para que quede claro qué productos destacaron en ventas en cada tienda.

# %%
def productos(productos: pd.DataFrame) -> pd.DataFrame:
    max_vendido = int(productos.groupby('Producto')[['Producto']].count().max().iloc[0])
    min_vendido = int(productos.groupby('Producto')[['Producto']].count().min().iloc[0])

    #print(max_vendido)
    #print(min_vendido)

    ventas = productos.groupby('Producto')[['Producto']].count()
    #print(tienda1_ventas)

    ventas.rename(
        columns={
            "Producto": "Cantidad",
        }
        , inplace=True
    )

    tienda_productos = ventas.query('Cantidad in (@max_vendido, @min_vendido)').sort_values(by='Cantidad', ascending=False)
    return tienda_productos

tienda1_productos = productos(tienda1)
tienda2_productos = productos(tienda2)
tienda3_productos = productos(tienda3)
tienda4_productos = productos(tienda4)

print('** Productos más y menos vendidos en cada tienda **')
print(f'\n** Tienda 1:')
print(f'\t\t {tienda1_productos}')

print(f'\n** Tienda 2:')
print(f'\t\t {tienda2_productos}')

print(f'\n** Tienda 3:')
print(f'\t\t {tienda3_productos}')

print(f'\n** Tienda 4:')
print(f'\t\t {tienda4_productos}')
# Out:
# ** Productos más y menos vendidos en cada tienda **
#
# ** Tienda 1:
# 		                            Cantidad
# Producto
# Armario                          60
# TV LED UHD 4K                    60
# Microondas                       60
# Celular ABXY                     33
# Auriculares con micrófono        33
#
# ** Tienda 2:
# 		                            Cantidad
# Producto
# Iniciando en programación        65
# Juego de mesa                    32
#
# ** Tienda 3:
# 		                          Cantidad
# Producto
# Kit de bancas                  57
# Bloques de construcción        35
#
# ** Tienda 4:
# 		                     Cantidad
# Producto
# Cama box                  62
# Guitarra eléctrica        33

# %%
import pandas as pd
import matplotlib.pyplot as plt
x='Producto'
y='Cantidad'
titulo = 'Productos más y menos vendidos por la Tienda '
tienda1_productos.plot(kind='bar', color='lightblue',xlabel=x,ylabel=y, title=titulo + '1')
tienda2_productos.plot(kind='bar', color='darkblue',xlabel=x,ylabel=y, title=titulo + '2')
tienda3_productos.plot(kind='bar', color='lightgreen',xlabel=x,ylabel=y, title=titulo + '3')
tienda4_productos.plot(kind='bar', color='green',xlabel=x,ylabel=y, title=titulo + '4')
# Out:
# <Axes: title={'center': 'Productos más y menos vendidos por la Tienda 4'}, xlabel='Producto', ylabel='Cantidad'>

# %% [markdown]
# # 5. Envío promedio por tienda

# %% [markdown]
# En este paso, debes calcular el costo de envío promedio para cada tienda. El objetivo es comprender cuánto se gasta, en promedio, en el envío de cada tienda.

# %%
tienda1_envio = round(tienda1['Costo de envío'].mean(), 2)
tienda2_envio = round(tienda2['Costo de envío'].mean(), 2)
tienda3_envio = round(tienda3['Costo de envío'].mean(), 2)
tienda4_envio = round(tienda4['Costo de envío'].mean(), 2)

print('** Costo de envío promedio por la tienda **')
print(f'Tienda 1: {tienda1_envio}')
print(f'Tienda 2: {tienda2_envio}')
print(f'Tienda 3: {tienda3_envio}')
print(f'Tienda 4: {tienda4_envio}')
# Out:
# ** Costo de envío promedio por la tienda **
# Tienda 1: 26018.61
# Tienda 2: 25216.24
# Tienda 3: 24805.68
# Tienda 4: 23459.46

# %% [markdown]
# # **Generando gráfico**

# %% [markdown]
#  Los gráficos deben complementar el análisis realizado, resaltando los puntos más relevantes, como los ingresos de la tienda, la distribución de categorías de productos, las opiniones de los clientes, los productos más vendidos y/o los costes de envío.

# %% [markdown]
# ## **1. Ingreso total por cada tienda**

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

# Datos: DataFrames por tienda
ventas_tiendas = [ventas_tienda1, ventas_tienda2, ventas_tienda3, ventas_tienda4]
ventas_tiendas_ordenadas = sorted(ventas_tiendas, reverse=True)
tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']

# Encontrar índice del mayor valor
mayor_idx = ventas_tiendas_ordenadas[0]

# Crear lista de "explode": todos 0 excepto el mayor
explode = [0.1 if i == mayor_idx else 0 for i in range(len(ventas_tiendas))]

# Graficar pastel
plt.figure(figsize=(8, 8))
plt.pie(
    x=ventas_tiendas_ordenadas,
    labels=tiendas,
    autopct='%1.1f%%',
    startangle=140,
    explode=explode,
    shadow=True  # Efecto tipo 3D
)
plt.title('Ventas Totales por Tienda')
plt.axis('equal')  # Asegura que el pastel sea circular
plt.show()

# %% [markdown]
# ## **2. Ventas por categoría**

# %%
import matplotlib.pyplot as plt
import pandas as pd

def graficarVentas(df: pd.DataFrame, titulo: str):
    # Ordenar de mayor a menor
    df_ordenado = df.sort_values(by='Cantidad', ascending=True)  # ascendente para que las barras grandes queden arriba

    # Crear gráfico de barras horizontales
    plt.figure(figsize=(10, 6))
    plt.barh(df_ordenado.index, df_ordenado['Cantidad'], color='#1f77b4')

    # Títulos y etiquetas
    plt.title(titulo)
    plt.xlabel('Cantidad Vendida')
    plt.ylabel('Categoría del Producto')

    # Mostrar el valor en cada barra
    for index, value in enumerate(df_ordenado['Cantidad']):
        plt.text(value + 2, index, str(value), va='center', fontsize=9)

    plt.tight_layout()
    plt.show()


graficarVentas(ventas_categoria(tienda1), 'Ventas por Categoría. Tienda 1')
graficarVentas(ventas_categoria(tienda2), 'Ventas por Categoría. Tienda 2')
graficarVentas(ventas_categoria(tienda3), 'Ventas por Categoría. Tienda 3')
graficarVentas(ventas_categoria(tienda4), 'Ventas por Categoría. Tienda 4')

# %% [markdown]
# Pareto (productos más rentables)

# %%
# !pip install geopandas matplotlib pandas
# !pip install contextily
# Out:
# Requirement already satisfied: geopandas in /usr/local/lib/python3.11/dist-packages (1.0.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.11/dist-packages (from geopandas) (2.0.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.11/dist-packages (from geopandas) (0.11.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from geopandas) (24.2)
# Requirement already satisfied: pyproj>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from geopandas) (3.7.1)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from geopandas) (2.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from pyogrio>=0.7.2->geopandas) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Collecting contextily
#   Downloading contextily-1.6.2-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: geopy in /usr/local/lib/python3.11/dist-packages (from contextily) (2.4.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from contextily) (3.10.0)
# Collecting mercantile (from contextily)
#   Downloading mercantile-1.2.1-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from contextily) (11.2.1)
# Collecting rasterio (from contextily)
#   Downloading rasterio-1.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from contextily) (2.32.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from contextily) (1.5.1)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.11/dist-packages (from contextily) (2025.4.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.11/dist-packages (from geopy->contextily) (2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->contextily) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->contextily) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->contextily) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->contextily) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib->contextily) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->contextily) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->contextily) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->contextily) (2.9.0.post0)
# Requirement already satisfied: click>=3.0 in /usr/local/lib/python3.11/dist-packages (from mercantile->contextily) (8.2.1)
# Collecting affine (from rasterio->contextily)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.11/dist-packages (from rasterio->contextily) (25.3.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from rasterio->contextily) (2025.4.26)
# Collecting cligj>=0.5 (from rasterio->contextily)
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting click-plugins (from rasterio->contextily)
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->contextily) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->contextily) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->contextily) (2.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->contextily) (1.17.0)
# Downloading contextily-1.6.2-py3-none-any.whl (17 kB)
# Downloading mercantile-1.2.1-py3-none-any.whl (14 kB)
# Downloading rasterio-1.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 81.5 MB/s eta 0:00:00
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Installing collected packages: mercantile, cligj, click-plugins, affine, rasterio, contextily
# Successfully installed affine-2.4.0 click-plugins-1.1.1 cligj-0.7.2 contextily-1.6.2 mercantile-1.2.1 rasterio-1.4.3

# %% [markdown]
# 1. Los ingresos de la tienda
# 2. La distribución de categorías de productos
# 3. Las opiniones de los clientes, los productos más vendidos/evaluados
# 4. Los costes de envío
# 5. Mejor vendedor en cada tienda y de todas las tiendas

# %% [markdown]
# # **Resumen**

# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
import contextily as ctx

tienda1['Tienda'] = 'Tienda 1'
tienda2['Tienda'] = 'Tienda 2'
tienda3['Tienda'] = 'Tienda 3'
tienda4['Tienda'] = 'Tienda 4'
tienda1['Ventas'] = ventas_tienda1
tienda2['Ventas'] = ventas_tienda2
tienda3['Ventas'] = ventas_tienda3
tienda4['Ventas'] = ventas_tienda4


# Unir todos los datos
ventas = pd.concat([tienda1, tienda2, tienda3, tienda4])

# %% [markdown]
# ## **1. Categorias Destacadas**

# %% [markdown]
# \
# De los datos se concluye que ciertas categorias de productos generan mas altos ingresos con un bajo costo de envío promedio, lo cual los hace altamente rentables. Estos productos deben ser destacados en promociones y mantenidos con buen stock para maximizar beneficios.

# %%
categorias = ventas["Categoría del Producto"].value_counts()
# ------------
# Gráfico de pastel: Distribución por categoría
# ------------
plt.figure(figsize=(6, 6))
plt.pie(categorias, labels=categorias.index, autopct='%1.1f%%', startangle=140)
plt.title("Distribución por Categoría de Productos en todas las Tiendas")
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **2. Costes de Envío**

# %% [markdown]
# El análisis detallado por producto también permitió identificar aquellos que, además de ser muy rentables, presentan costos logísticos bajos. Este tipo de producto debe ser priorizado en futuras campañas comerciales.

# %%
# Agrupar por tienda y calcular ingresos y costes de envío
resumen = ventas.groupby("Tienda").agg({
    "Precio": "sum",
    "Costo de envío": "sum"
}).reset_index()

# -------------------------------
# Gráfico de líneas – Costes de envío por tienda
# -------------------------------
# Gráfico combinado
fig, ax1 = plt.subplots(figsize=(8, 6))

# Barras para ingresos
ax1.bar(resumen["Tienda"], resumen["Precio"], color='skyblue', label="Ingresos")
ax1.set_ylabel("Ingresos", color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# Eje secundario para costos de envío
ax2 = ax1.twinx()
ax2.plot(resumen["Tienda"], resumen["Costo de envío"], color='red', marker='o', linewidth=2, label="Costo de envío")
ax2.set_ylabel("Costo de envío", color='red')
ax2.tick_params(axis='y', labelcolor='red')

# Título y leyenda
plt.title("Ingresos vs. Costos de Envío por Tienda")
fig.tight_layout()
plt.show()

# %% [markdown]
# ## **3. Calificaciones de Productos**

# %% [markdown]
# El análisis del promedio de calificaciones revela que los productos más vendidos no siempre son los mejor evaluados. Se sugiere revisar de porque el producto "Modelado predictivo" esta mal evaluado por los clientes, dado a su puntuación baja.

# %%
# -------------------------------
# Gráfico combinado: Opiniones (Calificación) vs Productos más evaluados
# -------------------------------
# Obtener los productos con más evaluaciones (más registros)
evaluaciones = ventas.groupby("Producto").agg({
    "Calificación": ["count", "mean"]
}).reset_index()

evaluaciones.columns = ["Producto", "Cantidad_Evaluaciones", "Promedio_Calificación"]
top_productos = evaluaciones.sort_values("Cantidad_Evaluaciones", ascending=False).head(10)

fig, ax1 = plt.subplots(figsize=(10, 5))

# Barras: Cantidad de evaluaciones
ax1.bar(top_productos["Producto"], top_productos["Cantidad_Evaluaciones"], color="lightgreen", label="Evaluaciones")
ax1.set_ylabel("Cantidad de Evaluaciones", color="green")
ax1.tick_params(axis='y', labelcolor='green')
ax1.set_xticklabels(top_productos["Producto"], rotation=45, ha='right')

# Línea: Promedio de calificación
ax2 = ax1.twinx()
ax2.plot(top_productos["Producto"], top_productos["Promedio_Calificación"], color="red", marker='o', label="Promedio Calificación")
ax2.set_ylabel("Promedio de Calificación", color="red")
ax2.tick_params(axis='y', labelcolor='red')

plt.title("Productos Más Evaluados y Opiniones")
fig.tight_layout()
plt.show()
# Out:
# <ipython-input-117-ef215e706567>:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(top_productos["Producto"], rotation=45, ha='right')

# %% [markdown]
# ## **4. Vendedores Destacados a Premiar**

# %% [markdown]
# Segun el grafico de los mejores vendedores de cada tienda, la vendedora Maria Alonso es quien mas ventas se genero en las Tienda 1 y Tienda 3.

# %%
def mejor_vendedor(df: pd.DataFrame) -> pd.DataFrame:
  ventas_por_vendedor = df.groupby(['Tienda', 'Vendedor'])['Precio'].sum().reset_index()
  mejor_por_tienda = ventas_por_vendedor.sort_values('Precio', ascending=False).head(1)
  return mejor_por_tienda

# Unir todos los datos de mejores vendedores en cada tienda
ventas_vendedor = []
for df in [tienda1, tienda2, tienda3, tienda4]:
  ventas_vendedor.append(mejor_vendedor(df))

mejores_vendedores = pd.DataFrame(columns=['Tienda', 'Vendedor', 'Total de Ventas'])
mejores_vendedores[['Tienda', 'Vendedor', 'Total de Ventas']] = pd.concat(ventas_vendedor, ignore_index=True)
mejores_vendedores.sort_values(by='Total de Ventas', inplace=True, ascending=False)
mejores_vendedores.reset_index(drop=True, inplace=True)
print(mejores_vendedores)


# Gráfico de torta
plt.figure(figsize=(8, 6))
plt.pie(mejores_vendedores['Total de Ventas'], labels=mejores_vendedores['Tienda'] + ':' + mejores_vendedores['Vendedor'], autopct='%1.1f%%', startangle=140)
plt.title('Top Mejores Vendedores de cada Tienda)')
plt.axis('equal')  # Asegura que el gráfico sea un círculo
plt.show()
# Out:
#      Tienda         Vendedor  Total de Ventas
# 0  Tienda 1    Maria Alfonso      101528700.0
# 1  Tienda 3    Maria Alfonso       96328500.0
# 2  Tienda 4    Felipe Santos       95432000.0
# 3  Tienda 2  Izabela de León       91812200.0
